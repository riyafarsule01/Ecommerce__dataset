# %% [markdown]
# <a href="https://colab.research.google.com/github/kamali1331/E-commerce-Return-Rate-Reduction-Analysis/blob/main/E_commerce_return_data_analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/ecommerce_customer_data_custom_ratios.csv') #E-commerce data

# %%
df.describe()
# Out:
#          Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.000000  250000.000000  250000.000000          250000.000000
# mean    25017.632092     254.742724       3.004936            2725.385196
# std     14412.515718     141.738104       1.414737            1442.576095
# min         1.000000      10.000000       1.000000             100.000000
# 25%     12590.000000     132.000000       2.000000            1476.000000
# 50%     25011.000000     255.000000       3.000000            2725.000000
# 75%     37441.250000     377.000000       4.000000            3975.000000
# max     50000.000000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age         Churn
# count  250000.000000  202618.000000  250000.000000  250000.00000
# mean       43.798276       0.500824      43.798276       0.20052
# std        15.364915       0.500001      15.364915       0.40039
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product Category', 'Product Price',
#        'Quantity', 'Total Purchase Amount', 'Payment Method', 'Customer Age',
#        'Returns', 'Customer Name', 'Age', 'Gender', 'Churn'],
#       dtype='object')

# %%
import pandas as pd
df=pd.read_csv('/ecommerce_customer_data_large.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-2d0f8bff5424> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('/ecommerce_customer_data_large.csv')
#       3 df.head()
#
# ...

# %%
import pandas as pd
import os # Import the os module to interact with the operating system

# Check if the file exists at the specified path
file_path = '/ecommerce_customer_data_large.csv'
if os.path.exists('/content/ecommerce_customer_data_large.csv'):
    print(f"File found at: ('/content/ecommerce_customer_data_large.csv")
    df=pd.read_csv('/content/ecommerce_customer_data_large.csv')
    df.head()
else:
    print(f"File not found at: {'/content/ecommerce_customer_data_large.csv'}")
    print("Checking files in the current directory:")
    # Get the current working directory
    current_directory = os.getcwd()
    print(f"Current directory:'/content/ecommerce_customer_data_large.csv")
    # List all files and directories in the current directory
    files_in_directory = os.listdir(current_directory)
    print("Files and directories in the current directory:")
    for item in files_in_directory:
        print(item)

    # You might need to adjust the file_path based on the output
    # For example, if the file is in a subdirectory named 'data', you might use:
    # file_path = './data/ecommerce_customer_data_large.csv'
    # df=pd.read_csv(file_path)
    # df.head()

# %%
# The rest of your code can follow here after the file is successfully loaded
# df.columns
# %%
# df.isnull().sum()
# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# sns.pairplot(df)
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# labels=df['Quality'].value_counts().index
# sizes=df['Total amount purchase'].value_counts().values

# plt.show()

# %%
# df.head()
# %%
# df.info()
# Out:
# File found at: ('/content/ecommerce_customer_data_large.csv

# %%
df.columns
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product Category', 'Product Price',
#        'Quantity', 'Total Purchase Amount', 'Payment Method', 'Customer Age',
#        'Returns', 'Customer Name', 'Age', 'Gender', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47382
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels=df['count'].value_counts().index
sizes=df['Total amount purchase'].value_counts().values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Quality')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-f029fa8cf40a> in <cell line: 0>()
#       2 import seaborn as sns
#       3
# ...

# %%
df.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Print columns to verify the correct column name
print(df.columns)

# Replace 'YOUR_ACTUAL_COLUMN_NAME_FOR_LABELS' with the actual column name
# for example, if 'Category' is the column you want to use for labels, replace it with 'Category'

# Based on the previous cell output, let's assume 'Purchase Amount (USD)' is the correct column name
# If df.columns printout shows a different name, update 'Purchase Amount (IND)' accordingly.
try:
    # Still keep the check for 'Quality' if that's intended for labels
    labels = df['Quality'].value_counts().index
except KeyError:
    print("Warning: 'Quality' column not found. Please verify the correct column for labels from the list above.")
    # As a temporary fix or if you have a different column for labels, update here.
    # For example, using 'Customer ID' as a placeholder, replace with the actual label column name.
    if 'Customer ID' in df.columns:
        labels = df['Customer ID'].value_counts().index
    else:
        print("Error: Neither 'Quality' nor 'Customer ID' columns found. Cannot determine labels.")
        # Set labels to an empty list or handle the error appropriately
        labels = []


# Correct the column name used for sizes based on the print(df.columns) output
# Replace 'Total amount purchase' with the actual column name for the purchase amount
try:
    sizes = df['Purchase Amount (USD)'].value_counts().values # Corrected column name
    # If the pie chart should represent counts based on the labels, and sizes should be the counts
    # of the label categories, you should use labels.value_counts().values
    # For example, if labels = df['Quality'].value_counts().index, then sizes should be df['Quality'].value_counts().values
    # The current code is trying to pair the counts of 'count' labels with value counts of 'Total amount purchase',
    # which might not be the intended logic for a distribution pie chart.
    # Let's assume you want the distribution of the column used for labels (e.g., 'Quality' or 'count').
    # The 'sizes' should be the counts of each unique value in the column used for 'labels'.
    # Let's use the counts of the column used for labels
    if 'count' in df.columns: # Based on a previous cell trying to use df['count'] for labels
         labels = df['count'].value_counts().index
         sizes = df['count'].value_counts().values
         plt.title('Distribution of count') # Update title to reflect the data being plotted
    elif 'Quality' in df.columns: # If 'Quality' is indeed the intended label column
         labels = df['Quality'].value_counts().index
         sizes = df['Quality'].value_counts().values
         plt.title('Distribution of Quality') # Keep original title if Quality is used
    elif 'Customer ID' in df.columns: # If using Customer ID as a fallback for labels
         labels = df['Customer ID'].value_counts().index
         sizes = df['Customer ID'].value_counts().values
         plt.title('Distribution of Customer ID') # Update title

except KeyError as e:
    print(f"Error: Column not found for sizes: {e}. Please verify the correct column name from the list above.")
    sizes = [] # Set sizes to an empty list to prevent further errors


plt.figure(figsize=(8, 8))
# Ensure the number of labels matches the number of sizes for the pie chart
if len(labels) > 0 and len(labels) == len(sizes):
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.show()
elif len(labels) != len(sizes):
    print("Error: The number of labels and sizes do not match. Cannot create the pie chart.")
    print(f"Number of labels: {len(labels)}")
    print(f"Number of sizes: {len(sizes)}")
else:
    print("Error: Labels or sizes are empty. Cannot create the pie chart.")
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product Category', 'Product Price',
#        'Quantity', 'Total Purchase Amount', 'Payment Method', 'Customer Age',
#        'Returns', 'Customer Name', 'Age', 'Gender', 'Churn'],
#       dtype='object')
# ...
# Error: Column not found for sizes: 'Purchase Amount (USD)'. Please verify the correct column name from the list above.
# Error: The number of labels and sizes do not match. Cannot create the pie chart.
# Number of labels: 49661
# Number of sizes: 0

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# Assuming you want to see the distribution (counts) of values in the 'Quality' column
# Replace 'Quality' with the actual column name you want to use for the categories

if 'Quality' in df.columns:
    plt.figure(figsize=(10, 6)) # Adjust figure size as needed
    sns.countplot(data=df, x='Quality') # Use countplot for frequency of categories
    plt.title('Distribution of Quality Categories') # Update title
    plt.xlabel('Quality') # Update x-axis label
    plt.ylabel('Count') # Update y-axis label
    plt.xticks(rotation=45, ha='right') # Rotate labels if they overlap
    plt.tight_layout() # Adjust layout to prevent labels from overlapping
    plt.show()
elif 'count' in df.columns: # Example for the 'count' column
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x='count')
    plt.title('Distribution of counts')
    plt.xlabel('count')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    print("Neither 'Quality' nor 'count' columns found for creating countplot example.")
# Out:
# Neither 'Quality' nor 'count' columns found for creating countplot example.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check if the 'Quality' column exists in the DataFrame
if 'Quality' in df.columns:
    plt.figure(figsize=(10, 6)) # Create a figure and axes for the plot
    # Use seaborn's countplot to show the counts of observations in each category
    sns.countplot(data=df, x='Quality')
    plt.title('Distribution of Quality Levels') # Set the title of the plot
    plt.xlabel('Quality Level') # Set the label for the x-axis
    plt.ylabel('Number of Customers') # Set the label for the y-axis (which represents the count)
    plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they are long to prevent overlap
    plt.tight_layout() # Adjust layout to prevent labels from being cut off
    plt.show() # Display the plot
else:
    print("The 'Quality' column was not found in the DataFrame.")
    print("Available columns are:", df.columns.tolist()) # Print available columns to help identify the correct one
# Out:
# The 'Quality' column was not found in the DataFrame.
# Available columns are: ['Customer ID', 'Purchase Date', 'Product Category', 'Product Price', 'Quantity', 'Total Purchase Amount', 'Payment Method', 'Customer Age', 'Returns', 'Customer Name', 'Age', 'Gender', 'Churn']
